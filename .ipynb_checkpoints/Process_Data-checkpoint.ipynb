# %%
import pickle
import pandas as pd
import os



import numpy as np
from scipy import stats
import requests
from bs4 import BeautifulSoup
import pandas as pd
from subprocess import call

import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy


import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import KFold
import matplotlib.pyplot as plt
from sklearn.cross_validation import cross_val_score
from sklearn.preprocessing import MinMaxScaler
% matplotlib inline


from IPython.core.pylabtools import figsize
figsize(5,5)
plt.style.use('fivethirtyeight')

from sklearn.model_selection import learning_curve
#import diagnostic_plots

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
    
#chromedriver = "/home/williamcottrell72/Downloads/chromedriver_linux64/chromedriver" # path to the chromedriver executable
#os.environ["webdriver.chrome.driver"] = chromedriver

# %%
def get_polynomial_features(degree, x_values):
    return PolynomialFeatures(degree=degree).fit_transform(x_values)


def build_df():
    test=1
    x=100
    data=[]
    while test:
        name=f'cach2_{x}.pkl'
        try:
            with open(name,'rb') as pkl:
                data_temp=pickle.load(pkl)
            data+=data_temp
            x+=100
        except:
            test=0
            return pd.DataFrame(data,columns=['url','stars','pics','descriptors','desLength','price'])    
        
def fix_row(row):
    return [float(x) for x in list(row)]

def clean_df():
    df=build_df()
    clean1=df.dropna().drop(columns=['url'])
    clean2=[]
    for i in range(clean1.shape[0]):
        try:
            clean_row=[fix_row(clean1.iloc[i])]
            clean2+=clean_row
        except:
            pass
    return pd.DataFrame(clean2,columns=['stars','pics','descriptors','desLength','price'])

# %%
df_wtf=clean_df()

# %%
df_wtf.shape
# Out:
# (4319, 5)

# %%
df_wtf.drop_duplicates()
# Out:
# (4039, 5)

# %%
df=clean_df()
df=df[df.price < 30]

# %%
row=df.iloc[3]
row
# Out:
# stars            4.20
# pics            11.00
# descriptors      4.00
# desLength      135.00
# price            5.95
# Name: 3, dtype: float64

# %%
df.head()
# Out:
#    stars  pics  descriptors  desLength  price
# 0    2.9  12.0          5.0      117.0   4.99
# 1    3.1  15.0          5.0      180.0   7.99
# 2    5.0  12.0          5.0      168.0  10.99
# 3    4.2  11.0          4.0      135.0   5.95
# 4    5.0  15.0          5.0      154.0  14.99

# %%
sns.heatmap(df.corr())

# %%
sns.pairplot(df, size = 1.2, aspect=1.5);

# %%
ytest=df.dropna().price
xtest=df.dropna().stars
plt.scatter(xtest.values,ytest.values)
plt.xlabel('Stars')
plt.ylabel("Price")
plt.show()

# %%
plt.hist(df['price'].apply(np.log).values,bins=np.arange(1,4,.2))
plt.show()

# %%
def transform(x):
    return 1/x**(.52)

# %%
mean_dL=np.mean(df['desLength'].apply(transform))

# %%
def t2(x):
    return abs(x)**(-.1)

# %%
plt.hist(df['desLength'].apply(transform).apply(lambda x: 50*(x-mean_dL)).values)
plt.show()

# %%
df['dL_transformed']=df['desLength'].apply(transform).apply(lambda x: 50*(x-mean_dL))

# %%
plt.hist(y.values,bins=np.arange(0,50,.1))
plt.show()

# %%
log_y=np.log(y)
plt.hist(log_y.values,bins=np.arange(0,6,.1))
plt.show()
df_lt=df
df['log_price']=log_y

# %%
mean_log_price=df['price'].apply(np.log).apply(np.mean)

# %%
plt.hist(df['log_price'],bins=np.arange(0,6,.1))
plt.show()

# %%
y=df['log_price'].dropna()
x=df.dropna()[['stars','pics','descriptors','dL_transformed']]

# %% [markdown]
# ## Let's play around with sklearn, assuming a model linear in the features.

# %%
lr = LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(x.values, y.values, test_size=0.3,random_state=42)
lr.fit(X_train, np.log(y_train))
lr.score(X_train,np.log(y_train)), lr.score(X_test, np.log(y_test))
# Out:
# (0.03832657698397779, 0.05720048434925217)

# %%
poly_features=[get_polynomial_features(i,X_train) for i in range(1,5)]
poly_features_test=[get_polynomial_features(i,X_test) for i in range(1,5)]

# %%
# Out:
# array([[ 7.49],
#        [ 5.99],
#        [11.99],
#        ...,
#        [ 8.98],
#        [14.99],
#        [ 6.39]])

# %%
for i in range(1,5):
    lr.fit(poly_features[i-1], np.log(y_train))
    print(lr.score(poly_features[i-1],np.log(y_train)),lr.score(poly_features_test[i-1],np.log(y_test)))
# Out:
# 0.03832657698397779 0.05720048434925195
# 0.05845143911509643 0.05917627824628958
# 0.07061986915854035 0.053621737140665426
# 0.09521682532434061 -0.19407657564414182

# %%
degree=2

est = make_pipeline(PolynomialFeatures(degree), LinearRegression())

# Fit our model to the training data
est.fit(X_train, np.log(y_train))

est.score(X_train,np.log(y_train))
# Plot the results
#plot_approximation(est, ax, label='degree=%d' % degree)
# Out:
# 0.05845143911509643

# %%
scores = cross_val_score(est, X_train, np.log(y_train), cv=4, scoring='mean_squared_error')
# Out:
# /home/williamcottrell72/anaconda3/lib/python3.6/site-packages/sklearn/metrics/scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /home/williamcottrell72/anaconda3/lib/python3.6/site-packages/sklearn/metrics/scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /home/williamcottrell72/anaconda3/lib/python3.6/site-packages/sklearn/metrics/scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# ...

# %%
print(-np.mean(scores))
# Out:
# 0.2132587094157053

# %%
y_log_pred_new=est.predict(X_train)
y_log_pred_test=est.predict(X_test)

# %%
est.score(X_test,np.log(y_test))
# Out:
# 0.05917627824628958

# %%
#Make new dataframe where new rows have new names.

# %%
df.head()
# Out:
#    stars  pics  descriptors  desLength  price  log_price  dL_transformed
# 0    2.9  12.0          5.0      117.0   4.99   1.607436        0.357580
# 1    3.1  15.0          5.0      180.0   7.99   2.078191       -0.538141
# 2    5.0  12.0          5.0      168.0  10.99   2.396986       -0.407337
# 3    4.2  11.0          4.0      135.0   5.95   1.783391        0.038394
# 4    5.0  15.0          5.0      154.0  14.99   2.707383       -0.235806

# %%
y, X = patsy.dmatrices('price ~ dL_transformed+descriptors+stars+pics + pics**2+dL_transformed**2+descriptors**2', data=df, return_type="dataframe")

# Create your model
model = sm.OLS(y,X)
# Fit your model to your training set
fit = model.fit()
# Print summary statistics of the model's performance
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     40.31
# Date:                Sat, 14 Jul 2018   Prob (F-statistic):           2.54e-33
# Time:                        12:32:54   Log-Likelihood:                -15138.
# No. Observations:                5336   AIC:                         3.029e+04
# Df Residuals:                    5331   BIC:                         3.032e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
fit.resid.plot(style='o', figsize=(12,8));

# %% [markdown]
# ## Regression with sklearn

# %%
df.head()
# Out:
#    stars  pics  descriptors  desLength  price
# 0    2.9  12.0          5.0      117.0   4.99
# 1    3.1  15.0          5.0      180.0   7.99
# 2    5.0  12.0          5.0      168.0  10.99
# 3    4.2  11.0          4.0      135.0   5.95
# 4    5.0  15.0          5.0      154.0  14.99

# %%
df2=df[['stars','pics','descriptors','dL_transformed','log_price']]
df2.head()
# Out:
#    stars  pics  descriptors  dL_transformed  log_price
# 0    2.9  12.0          5.0        0.357580   1.607436
# 1    3.1  15.0          5.0       -0.538141   2.078191
# 2    5.0  12.0          5.0       -0.407337   2.396986
# 3    4.2  11.0          4.0        0.038394   1.783391
# 4    5.0  15.0          5.0       -0.235806   2.707383

# %%
# Create an empty model
lr = LinearRegression()

# Choose the predictor variables, here all but the first which is the response variable
# This model is analogous to the Y ~ X1 + X2 + X3 + X4 + X5 + X6 model
x_array = df.iloc[:,:4]
# Choose the response variable(s)
y_array = df.iloc[:,4]
# Fit the model to the full dataset
lr.fit(x_array,y_array)
# Print out the R^2 for the model against the full dataset
lr.score(x_array,y_array)

#sm.OLS(y,sm.add_constant(X)).fit().summary()#, #print(lr.score(X,y))
# Out:
# 0.027802358823613923

# %%
x2= get_polynomial_features(2,X_train)
x3=get_polynomial_features(3,X_train)
x4=get_polynomial_features(4,X_train)

x2_test= get_polynomial_features(2,X_test)
x3_test=get_polynomial_features(3,X_test)
x4_test=get_polynomial_features(4,X_test)

# %%
lr.fit(x3,y)
lr.score(x3,y)
# Out:
# 0.03842825024498142

# %%
lr.fit(x2,y_train)
# Print out the R^2 for the model against the full dataset
lr.score(x2,y_train)
# Out:
# 0.023115419207043852

# %%
log_y_pred=lr.predict(x2)

# %%
z=y_train-log_y_pred

# %%
plt.hist(z,bins=np.arange(-10,10,.1))
plt.show()

# %%
plt.scatter(np.log(y_train),z,alpha=.05)
plt.xlabel("Actual Values")
plt.ylabel("Residuals")
plt.show()

# %%
yz=list(zip(np.log(y_train),z))
yz_filt=filter(lambda x: float(x[0]) <30,yz)

# %%
yz_filt

# %%
y_new=[]
z_new=[]
for x in yz_filt:
    y_new.append(float(x[0]))
    z_new.append(float(x[1]))

# %%
plt.scatter(y_new,z_new,alpha=.01)
plt.xlabel("Actual Values")
plt.ylabel("Residuals")
plt.show()

# %%
lr.coef_
# Out:
# array([[ 0.00000000e+00, -2.73355781e-02,  1.93614467e+00,
#         -3.17899055e+00,  4.20839156e-02,  1.55082819e-01,
#         -7.47714211e-02, -1.23249107e-02, -1.52931375e-03,
#         -2.30666125e-02, -1.09315007e-01, -1.42095665e-03,
#          4.25084013e-01,  3.23746631e-03, -9.81936512e-05]])

# %%
x2[5]
# Out:
# array([1.0000e+00, 2.7000e+00, 1.3000e+01, 6.0000e+00, 1.4600e+02,
#        7.2900e+00, 3.5100e+01, 1.6200e+01, 3.9420e+02, 1.6900e+02,
#        7.8000e+01, 1.8980e+03, 3.6000e+01, 8.7600e+02, 2.1316e+04])

# %%
plt.scatter(x2, y,  color='black')
plt.plot(x2, y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-462-7f5fa9c7ce03> in <module>()
# ----> 1 plt.scatter(x2, y,  color='black')
#       2 plt.plot(x2, y_pred, color='blue', linewidth=3)
#       3
#       4 plt.xticks(())
#       5 plt.yticks(())
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3468                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3469                          linewidths=linewidths, verts=verts,
# -> 3470                          edgecolors=edgecolors, data=data, **kwargs)
#    3471     finally:
#    3472         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
# ...

# %% [markdown]
# ## Let's go back to stats models but with some new features.

# %%
#Strategy: Use poly features to generate poly, then convert back to dataframe.
x_array = df.iloc[:,:4]
x_squared=get_polynomial_features(2,x_array)

# %%
x_squared_df=pd.DataFrame(x_squared)

# %%
len(y.values)
# Out:
# 3180

# %%
x_squared_df.shape
# Out:
# (3180, 15)

# %%
x_squared_values=x_squared_df.values

# %%
yv=[float(i) for i in y.values]

# %%
lr2 = LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(x_squared_values, yv, test_size=0.3)
lr2.fit(X_train, y_train)
lr2.score(X_train,y_train), lr.score(X_test, y_test)
# Out:
# (0.033895700719542954, -0.001674556322433851)

# %% [markdown]
# ## Let's try learning curve!

# %%
x_array.shape
# Out:
# (3180, 4)

# %%
quad_features = PolynomialFeatures(2).fit_transform(x_array.values)
model = LinearRegression()

#outputs three arrays:
# amount of data used per test, 
# training scores (one row per test, one column per group),
# test scores (one row per test, one column per group)
learning_curve(model, quad_features, yv, cv= 4)
# Out:
# (array([ 238,  775, 1311, 1848, 2385]),
#  array([[0.11382723, 0.09276972, 0.09276972, 0.09276972],
#         [0.04199762, 0.04190412, 0.04190412, 0.04190412],
#         [0.04817682, 0.04294137, 0.03406608, 0.03406608],
#         [0.03279238, 0.03530069, 0.02974499, 0.02727094],
#         [0.0303222 , 0.03076442, 0.02679498, 0.03060771]]),
#  array([[ 1.25165964e-02, -7.34285619e-01, -5.87079129e-01,
#          -7.80663079e-01],
#         [ 1.30910034e-02, -7.93148449e-02, -2.15755535e-02,
#          -1.04296764e-01],
#         [ 1.22761593e-02, -3.75934565e-02,  1.25091280e-02,
#          -4.10664649e-02],
#         [ 2.17957212e-02, -1.29439936e-02,  1.11483988e-02,
#          -9.15917945e-04],
#         [ 1.96396209e-02,  2.62107025e-04,  1.33783810e-02,
#          -1.27202982e-02]]))

# %%
train_sizes, train_scores, test_scores = learning_curve(model, quad_features, yv, cv= 4)

# %%
ave_train_scores = train_scores.mean(axis=1)
ave_test_scores = test_scores.mean(axis=1)

# %%
learn_df = pd.DataFrame({
    'train_size': train_sizes,
    'train_score': ave_train_scores,
    'test_score': ave_test_scores
})
learn_df
# Out:
#    train_size  train_score  test_score
# 0         238     0.098034   -0.522378
# 1         775     0.041927   -0.048024
# 2        1311     0.039813   -0.013469
# 3        1848     0.031277    0.004771
# 4        2385     0.029622    0.005140

# %%
plt.plot(learn_df['train_size'], learn_df['train_score'], 'r--o', label='train scores')
plt.plot(learn_df['train_size'], learn_df['test_score'], 'b--x', label='test size')
plt.legend(loc='lower right')
plt.ylim(-1,1)
# Out:
# (-1, 1)

# %%
y, X = patsy.dmatrices('price ~ desLength+descriptors+stars+pics + pics**2+desLength**2+descriptors**2', data=df, return_type="dataframe")

# Create your model
model = sm.OLS(y,X)
# Fit your model to your training set
fit = model.fit()
# Print summary statistics of the model's performance
fit.summary()

# %%
os.system("cd ..")
# Out:
# 0

# %%
file_list=!ls

# %%
os.getcwd()
# Out:
# '/home/williamcottrell72/ds/metis/metisgh/project_luther'
